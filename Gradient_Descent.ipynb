# %%
import numpy as np


def gradient_descent (f , initial_point,learning_rate,iterations):
  point=initial_point.copy()
  history=[]


  for _ in range (iterations):
    #compute the gradient of the function at the current point
    gradient=np.array([2 *point[0],2*point[1]])


    #update point using gradient descent update rule
    point=learning_rate * gradient

    #calculate the value of the function at the updated point
    value=f(point[0],point[1])


    #save the history of points and function values
    history.append((point.copy(),value))


    print("values of the points and objectives function value are :{} and{}".format(point,value))
  return point, history


def objective_function(x,y):
  return x*2 +y*2 +4


# Define initial point, learning rate, and the number of the iterations
initial_point=np.array([1.0, 1.0])
learning_rate=0.1
iterations=100


#run gradient descent
minimum_point, history = gradient_descent(objective_function, initial_point, learning_rate, iterations )


print("Minimum point (x,y):",minimum_point)
print("Minimum value of the function:",objective_function(*minimum_point))
# Out:
# values of the points and objectives function value are :[0.2 0.2] and4.8
# values of the points and objectives function value are :[0.04 0.04] and4.16
# values of the points and objectives function value are :[0.008 0.008] and4.032
# values of the points and objectives function value are :[0.0016 0.0016] and4.0064
# values of the points and objectives function value are :[0.00032 0.00032] and4.00128
# values of the points and objectives function value are :[6.4e-05 6.4e-05] and4.000256
# values of the points and objectives function value are :[1.28e-05 1.28e-05] and4.0000512
# values of the points and objectives function value are :[2.56e-06 2.56e-06] and4.00001024
# values of the points and objectives function value are :[5.12e-07 5.12e-07] and4.000002048
# values of the points and objectives function value are :[1.024e-07 1.024e-07] and4.0000004096
# values of the points and objectives function value are :[2.048e-08 2.048e-08] and4.00000008192
# values of the points and objectives function value are :[4.096e-09 4.096e-09] and4.000000016384
# values of the points and objectives function value are :[8.192e-10 8.192e-10] and4.0000000032768
# values of the points and objectives function value are :[1.6384e-10 1.6384e-10] and4.00000000065536
# values of the points and objectives function value are :[3.2768e-11 3.2768e-11] and4.000000000131072
# values of the points and objectives function value are :[6.5536e-12 6.5536e-12] and4.000000000026215
# values of the points and objectives function value are :[1.31072e-12 1.31072e-12] and4.000000000005243
# values of the points and objectives function value are :[2.62144e-13 2.62144e-13] and4.000000000001049
# values of the points and objectives function value are :[5.24288e-14 5.24288e-14] and4.00000000000021
# values of the points and objectives function value are :[1.048576e-14 1.048576e-14] and4.000000000000042
# values of the points and objectives function value are :[2.097152e-15 2.097152e-15] and4.000000000000008
# values of the points and objectives function value are :[4.194304e-16 4.194304e-16] and4.000000000000002
# values of the points and objectives function value are :[8.388608e-17 8.388608e-17] and4.0
# values of the points and objectives function value are :[1.6777216e-17 1.6777216e-17] and4.0
# values of the points and objectives function value are :[3.3554432e-18 3.3554432e-18] and4.0
# values of the points and objectives function value are :[6.7108864e-19 6.7108864e-19] and4.0
# values of the points and objectives function value are :[1.34217728e-19 1.34217728e-19] and4.0
# values of the points and objectives function value are :[2.68435456e-20 2.68435456e-20] and4.0
# values of the points and objectives function value are :[5.36870912e-21 5.36870912e-21] and4.0
# values of the points and objectives function value are :[1.07374182e-21 1.07374182e-21] and4.0
# values of the points and objectives function value are :[2.14748365e-22 2.14748365e-22] and4.0
# values of the points and objectives function value are :[4.2949673e-23 4.2949673e-23] and4.0
# values of the points and objectives function value are :[8.58993459e-24 8.58993459e-24] and4.0
# values of the points and objectives function value are :[1.71798692e-24 1.71798692e-24] and4.0
# values of the points and objectives function value are :[3.43597384e-25 3.43597384e-25] and4.0
# values of the points and objectives function value are :[6.87194767e-26 6.87194767e-26] and4.0
# values of the points and objectives function value are :[1.37438953e-26 1.37438953e-26] and4.0
# values of the points and objectives function value are :[2.74877907e-27 2.74877907e-27] and4.0
# values of the points and objectives function value are :[5.49755814e-28 5.49755814e-28] and4.0
# values of the points and objectives function value are :[1.09951163e-28 1.09951163e-28] and4.0
# values of the points and objectives function value are :[2.19902326e-29 2.19902326e-29] and4.0
# values of the points and objectives function value are :[4.39804651e-30 4.39804651e-30] and4.0
# values of the points and objectives function value are :[8.79609302e-31 8.79609302e-31] and4.0
# values of the points and objectives function value are :[1.7592186e-31 1.7592186e-31] and4.0
# values of the points and objectives function value are :[3.51843721e-32 3.51843721e-32] and4.0
# values of the points and objectives function value are :[7.03687442e-33 7.03687442e-33] and4.0
# values of the points and objectives function value are :[1.40737488e-33 1.40737488e-33] and4.0
# values of the points and objectives function value are :[2.81474977e-34 2.81474977e-34] and4.0
# values of the points and objectives function value are :[5.62949953e-35 5.62949953e-35] and4.0
# values of the points and objectives function value are :[1.12589991e-35 1.12589991e-35] and4.0
# values of the points and objectives function value are :[2.25179981e-36 2.25179981e-36] and4.0
# values of the points and objectives function value are :[4.50359963e-37 4.50359963e-37] and4.0
# values of the points and objectives function value are :[9.00719925e-38 9.00719925e-38] and4.0
# values of the points and objectives function value are :[1.80143985e-38 1.80143985e-38] and4.0
# values of the points and objectives function value are :[3.6028797e-39 3.6028797e-39] and4.0
# values of the points and objectives function value are :[7.2057594e-40 7.2057594e-40] and4.0
# values of the points and objectives function value are :[1.44115188e-40 1.44115188e-40] and4.0
# values of the points and objectives function value are :[2.88230376e-41 2.88230376e-41] and4.0
# values of the points and objectives function value are :[5.76460752e-42 5.76460752e-42] and4.0
# values of the points and objectives function value are :[1.1529215e-42 1.1529215e-42] and4.0
# values of the points and objectives function value are :[2.30584301e-43 2.30584301e-43] and4.0
# values of the points and objectives function value are :[4.61168602e-44 4.61168602e-44] and4.0
# values of the points and objectives function value are :[9.22337204e-45 9.22337204e-45] and4.0
# values of the points and objectives function value are :[1.84467441e-45 1.84467441e-45] and4.0
# values of the points and objectives function value are :[3.68934881e-46 3.68934881e-46] and4.0
# values of the points and objectives function value are :[7.37869763e-47 7.37869763e-47] and4.0
# values of the points and objectives function value are :[1.47573953e-47 1.47573953e-47] and4.0
# values of the points and objectives function value are :[2.95147905e-48 2.95147905e-48] and4.0
# values of the points and objectives function value are :[5.9029581e-49 5.9029581e-49] and4.0
# values of the points and objectives function value are :[1.18059162e-49 1.18059162e-49] and4.0
# values of the points and objectives function value are :[2.36118324e-50 2.36118324e-50] and4.0
# values of the points and objectives function value are :[4.72236648e-51 4.72236648e-51] and4.0
# values of the points and objectives function value are :[9.44473297e-52 9.44473297e-52] and4.0
# values of the points and objectives function value are :[1.88894659e-52 1.88894659e-52] and4.0
# values of the points and objectives function value are :[3.77789319e-53 3.77789319e-53] and4.0
# values of the points and objectives function value are :[7.55578637e-54 7.55578637e-54] and4.0
# values of the points and objectives function value are :[1.51115727e-54 1.51115727e-54] and4.0
# values of the points and objectives function value are :[3.02231455e-55 3.02231455e-55] and4.0
# values of the points and objectives function value are :[6.0446291e-56 6.0446291e-56] and4.0
# values of the points and objectives function value are :[1.20892582e-56 1.20892582e-56] and4.0
# values of the points and objectives function value are :[2.41785164e-57 2.41785164e-57] and4.0
# values of the points and objectives function value are :[4.83570328e-58 4.83570328e-58] and4.0
# values of the points and objectives function value are :[9.67140656e-59 9.67140656e-59] and4.0
# values of the points and objectives function value are :[1.93428131e-59 1.93428131e-59] and4.0
# values of the points and objectives function value are :[3.86856262e-60 3.86856262e-60] and4.0
# values of the points and objectives function value are :[7.73712525e-61 7.73712525e-61] and4.0
# values of the points and objectives function value are :[1.54742505e-61 1.54742505e-61] and4.0
# values of the points and objectives function value are :[3.0948501e-62 3.0948501e-62] and4.0
# values of the points and objectives function value are :[6.1897002e-63 6.1897002e-63] and4.0
# values of the points and objectives function value are :[1.23794004e-63 1.23794004e-63] and4.0
# values of the points and objectives function value are :[2.47588008e-64 2.47588008e-64] and4.0
# values of the points and objectives function value are :[4.95176016e-65 4.95176016e-65] and4.0
# values of the points and objectives function value are :[9.90352031e-66 9.90352031e-66] and4.0
# values of the points and objectives function value are :[1.98070406e-66 1.98070406e-66] and4.0
# values of the points and objectives function value are :[3.96140813e-67 3.96140813e-67] and4.0
# values of the points and objectives function value are :[7.92281625e-68 7.92281625e-68] and4.0
# values of the points and objectives function value are :[1.58456325e-68 1.58456325e-68] and4.0
# values of the points and objectives function value are :[3.1691265e-69 3.1691265e-69] and4.0
# values of the points and objectives function value are :[6.338253e-70 6.338253e-70] and4.0
# values of the points and objectives function value are :[1.2676506e-70 1.2676506e-70] and4.0
# Minimum point (x,y): [1.2676506e-70 1.2676506e-70]
# Minimum value of the function: 4.0
